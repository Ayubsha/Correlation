# %%
#Importing required libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Reading the csv file as a pandas dataframe
df1=pd.read_csv(r"C:\Users\Abu Ayub\Desktop\BRP\Correlation diagram\long.csv")

# %%
df1.head(2)
# Out:
#    p_road  stor_cap  el_dom  el_ind  el_com  el_road_l  el_others  \
# 0    20.0     158.8    1050     364      34        227        0.0
# 1    31.0    4500.0    8353     107    1887       1372        4.0
#
#    total_light_cal_2  total_light_cal_1  total_light_cal0  total_light_cal1  \
# 0               26.0               32.0              27.0              27.0
# 1               92.0               96.0             102.0              98.0
#
#    total_light_cal2  total_forest_1  total_forest0  total_forest1
# 0              29.0             920           1037            691
# 1             101.0            2395           2201           2086

# %%
#Checking for dimensions of dataframe
print(df1.shape)
# Out:
# (4317, 15)

# %%
#Creating a correlation matrix
correlation_mat = df1.corr()

# %%
sns.heatmap(correlation_mat, annot = True)

# %%
#Getting complete list of correlation pairs
corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# p_road         p_road              1.000000
#                stor_cap            0.099412
#                el_dom              0.255925
#                el_ind              0.388042
#                el_com              0.653348
#                                      ...
# total_forest1  total_light_cal1    0.248300
#                total_light_cal2    0.240458
#                total_forest_1      0.985961
#                total_forest0       0.986516
#                total_forest1       1.000000
# Length: 225, dtype: float64

# %%
#Getting correlation pairs with correlation values greater that 0.5
strong_pairs = corr_pairs[abs(corr_pairs) > 0.5]

print(strong_pairs)
# Out:
# p_road         p_road               1.000000
#                el_com               0.653348
#                el_road_l            0.773320
#                total_light_cal_2    0.705164
#                total_light_cal_1    0.642867
#                                       ...
# total_forest0  total_forest0        1.000000
#                total_forest1        0.986516
# total_forest1  total_forest_1       0.985961
#                total_forest0        0.986516
#                total_forest1        1.000000
# Length: 79, dtype: float64
